# %%
path = "/content/drive/MyDrive/BracU/Summer-21/AAI/Project"
from google.colab import drive
drive.mount("/content/drive")
# %cd $path

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# # Dataset Processing
# ### The _DSEBD_ dataset is taken from the [https://www.kaggle.com/mahmudulhaque/dsebd](https://www.kaggle.com/mahmudulhaque/dsebd)
# ### It is divided into several json files. Each json files contains yearly trading info of companies registered to Dhaka Stock Exchange
#
# * The json files are loaded into pandas dataframe
# * Dataframes are merged into single frame
# * Entire frame is into csv format
# * A subset of dataframe is created with smaller number of attributes
# * Data for each companies are stored into separate csv files.

# %%
meta_json = 'securities.json'

info_frame = pd.read_json('dsebd/'+meta_json)
info_frame.to_csv('meta_data.csv', encoding='utf-8')
info_frame.describe()
# Out:
#        trading_code         sector instrument_type
# count           589            589             589
# unique          589             22               5
# top       NAVANACNG  Treasury Bond          Equity
# freq              1            221             321

# %%
info_frame['instrument_type'].unique()
# Out:
# array(['Equity', 'Mutual Fund', 'Corporate Bond', 'Debenture',
#        'Treasury Bond'], dtype=object)

# %%
info_frame.sample(5)
# Out:
#     trading_code                       sector instrument_type
# 82      BXPHARMA  Pharmaceuticals & Chemicals          Equity
# 275    POWERGRID                 Fuel & Power          Equity
# 369     T10Y0617                Treasury Bond   Treasury Bond
# 260          PDL                      Textile          Equity
# 389     T10Y0919                Treasury Bond   Treasury Bond

# %%
prices_jsons  = ['prices_2008.json','prices_2009.json','prices_2010.json',
              'prices_2011.json','prices_2012.json','prices_2013.json',
             'prices_2014.json','prices_2015.json','prices_2016.json',
             'prices_2017.json','prices_2018.json','prices_2019.json','prices_2020.json']

frame_list = []
for i in range(len(prices_jsons)):
    temp_frame = pd.read_json('dsebd/'+prices_jsons[i])
    #print(temp_frame.head())
    frame_list.append(temp_frame)

# %%
dse_frame = pd.concat(frame_list)
#dse_frame = dse_frame.set_index('date')
dse_frame.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1575134 entries, 0 to 116742
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   date                      1575134 non-null  datetime64[ns]
#  1   trading_code              1575134 non-null  object
#  2   last_traded_price         1575134 non-null  float64
#  3   high                      1575134 non-null  float64
#  4   low                       1575134 non-null  float64
#  5   opening_price             1575134 non-null  float64
#  6   closing_price             1575134 non-null  float64
#  7   yesterdays_closing_price  1575134 non-null  float64
#  8   trade                     1575134 non-null  int64
#  9   value_mn                  1575134 non-null  float64
#  10  volume                    1575134 non-null  int64
# dtypes: datetime64[ns](1), float64(7), int64(2), object(1)
# memory usage: 144.2+ MB

# %%
dse_frame.head()
# Out:
#          date trading_code  last_traded_price    high    low  opening_price  \
# 0  2008-12-30      1STBSRS             823.00  840.00  819.0          825.0
# 1  2008-12-28      1STBSRS             817.00  829.00  802.0          802.0
# 2  2008-12-24      1STBSRS             789.00  809.75  786.0          790.0
# 3  2008-12-23      1STBSRS             785.00  798.50  785.0          785.0
# 4  2008-12-22      1STBSRS             778.25  794.50  775.5          787.0
#
#    closing_price  yesterdays_closing_price  trade  value_mn  volume
# 0         826.25                    825.75     86    4.1475    5000
# 1         825.75                    790.00     59    2.7838    3400
# 2         790.00                    785.75     74    3.5270    4450
# 3         785.75                    782.50     38    2.0541    2600
# 4         782.50                    797.75     19    0.7825    1000

# %%
dse_frame.to_csv('dsebd.csv', encoding='utf-8', index=False)

# %%
dse_frame = pd.read_csv('dsebd.csv')
#dse_frame.head()

# %% [markdown]
# **create csv for each company**

# %%
company_list = info_frame['trading_code']
sub_frame = dse_frame.loc[:, ['date', 'trading_code', 'high', 'low', 'opening_price', 'closing_price', 
'yesterdays_closing_price', 'volume']]

sub_frame = sub_frame[~(sub_frame["opening_price"] == 0) | (sub_frame["closing_price"] == 0) | (sub_frame["high"] == 0)
    | (sub_frame["low"] == 0) | (sub_frame["yesterdays_closing_price"] == 0)]

sub_frame = sub_frame.sort_values(["date"], ascending=True)
sub_frame['date'] = pd.to_datetime(sub_frame['date'])
#sub_frame = sub_frame.set_index(["date"], inplace=True)

for i in range(len(info_frame)):
    company_code = company_list[i].strip()
    company_data = sub_frame[sub_frame['trading_code']==company_code]
    company_data.rename(columns=({ 'opening_price': 'open', 'closing_price': 'close',
    'yesterdays_closing_price':'prev_closing_price'}), inplace=True,)
   
    company_data.to_csv('./company_data/{company}.csv'.format(company=company_code),
    columns=['date', 'open', 'high', 'low', 'close', 'volume', 'prev_closing_price'],index=False)
    print(company_code, 'data saved as CSV')
# Out:
# C:\Users\raihan\Anaconda3\lib\site-packages\pandas\core\frame.py:4293: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# ABBANK data saved as CSV
# ACI data saved as CSV
# ACFL data saved as CSV
# AAMRATECH data saved as CSV
# 1JANATAMF data saved as CSV
# AAMRANET data saved as CSV
# ACMELAB data saved as CSV
# AFCAGRO data saved as CSV
# ACTIVEFINE data saved as CSV
# ADNTEL data saved as CSV
# ACIFORMULA data saved as CSV
# ADVENT data saved as CSV
# AL-HAJTEX data saved as CSV
# AGRANINS data saved as CSV
# AIBL1STIMF data saved as CSV
# ALARABANK data saved as CSV
# ABB1STMF data saved as CSV
# 1STPRIMFMF data saved as CSV
# AMCL(PRAN) data saved as CSV
# AMBEEPHA data saved as CSV
# AGNISYSL data saved as CSV
# AFTABAUTO data saved as CSV
# AIL data saved as CSV
# ALLTEX data saved as CSV
# APEXSPINN data saved as CSV
# APEXFOODS data saved as CSV
# ALIF data saved as CSV
# APEXTANRY data saved as CSV
# AMANFEED data saved as CSV
# APOLOISPAT data saved as CSV
# ARAMIT data saved as CSV
# ARGONDENIM data saved as CSV
# ASIAPACINS data saved as CSV
# ANWARGALV data saved as CSV
# ANLIMAYARN data saved as CSV
# APSCLBOND data saved as CSV
# BANGAS data saved as CSV
# BANKASIA data saved as CSV
# APEXFOOT data saved as CSV
# BARKAPOWER data saved as CSV
# BATASHOE data saved as CSV
# ARAMITCEM data saved as CSV
# ASIAINS data saved as CSV
# BATBC data saved as CSV
# BDAUTOCA data saved as CSV
# BBSCABLES data saved as CSV
# ATCSLGF data saved as CSV
# BDFINANCE data saved as CSV
# ATLASBANG data saved as CSV
# BDLAMPS data saved as CSV
# BEACHHATCH data saved as CSV
# BDWELDING data saved as CSV
# BENGALWTL data saved as CSV
# BEACONPHAR data saved as CSV
# AZIZPIPES data saved as CSV
# BGIC data saved as CSV
# BIFC data saved as CSV
# BAYLEASING data saved as CSV
# BDCOM data saved as CSV
# BBS data saved as CSV
# BRACBANK data saved as CSV
# BDSERVICE data saved as CSV
# BDTHAI data saved as CSV
# BSC data saved as CSV
# BSRMLTD data saved as CSV
# BSCCL data saved as CSV
# BSRMSTEEL data saved as CSV
# CAPMBDBLMF data saved as CSV
# CENTRALINS data saved as CSV
# CAPMIBBLMF data saved as CSV
# BEXIMCO data saved as CSV
# BERGERPBL data saved as CSV
# CITYGENINS data saved as CSV
# CENTRALPHL data saved as CSV
# CNATEX data saved as CSV
# CONFIDCEM data saved as CSV
# BPML data saved as CSV
# BNICL data saved as CSV
# DACCADYE data saved as CSV
# DAFODILCOM data saved as CSV
# DBH data saved as CSV
# BXSYNTH data saved as CSV
# BXPHARMA data saved as CSV
# DEBARACEM data saved as CSV
# CITYBANK data saved as CSV
# DEBBDZIPP data saved as CSV
# DEBBXDENIM data saved as CSV
# CONTININS data saved as CSV
# COPPERTECH data saved as CSV
# DEBBXKNI data saved as CSV
# DEBBXTEX data saved as CSV
# DELTALIFE data saved as CSV
# DESCO data saved as CSV
# DESHBANDHU data saved as CSV
# CVOPRL data saved as CSV
# DHAKAINS data saved as CSV
# DEBBDWELD data saved as CSV
# DBH1STMF data saved as CSV
# DEBBDLUGG data saved as CSV
# DUTCHBANGL data saved as CSV
# DSSL data saved as CSV
# DULAMIACOT data saved as CSV
# EASTRNLUB data saved as CSV
# DEBBXFISH data saved as CSV
# EASTLAND data saved as CSV
# EBLNRBMF data saved as CSV
# EBL1STMF data saved as CSV
# DELTASPINN data saved as CSV
# EMERALDOIL data saved as CSV
# DOREENPWR data saved as CSV
# DHAKABANK data saved as CSV
# ENVOYTEX data saved as CSV
# DSHGARME data saved as CSV
# ESQUIRENIT data saved as CSV
# EXIMBANK data saved as CSV
# EASTERNINS data saved as CSV
# FAREASTFIN data saved as CSV
# EBL data saved as CSV
# FAREASTLIF data saved as CSV
# ECABLES data saved as CSV
# FASFIN data saved as CSV
# EHL data saved as CSV
# FINEFOODS data saved as CSV
# FEDERALINS data saved as CSV
# FEKDIL data saved as CSV
# FORTUNE data saved as CSV
# ETL data saved as CSV
# FUWANGFOOD data saved as CSV
# FAMILYTEX data saved as CSV
# EXIM1STMF data saved as CSV
# GENEXIL data saved as CSV
# GBBPOWER data saved as CSV
# FARCHEM data saved as CSV
# GEMINISEA data saved as CSV
# GHAIL data saved as CSV
# GENNEXT data saved as CSV
# FBFIF data saved as CSV
# GP data saved as CSV
# FIRSTSBANK data saved as CSV
# FIRSTFIN data saved as CSV
# GQBALLPEN data saved as CSV
# FUWANGCER data saved as CSV
# GREENDELT data saved as CSV
# GRAMEENS2 data saved as CSV
# GSPFINANCE data saved as CSV
# GLAXOSMITH data saved as CSV
# GHCL data saved as CSV
# GLOBALINS data saved as CSV
# HFL data saved as CSV
# GOLDENSON data saved as CSV
# IBNSINA data saved as CSV
# HWAWELLTEX data saved as CSV
# ICB data saved as CSV
# IBP data saved as CSV
# GPHISPAT data saved as CSV
# GREENDELMF data saved as CSV
# ICBAMCL2ND data saved as CSV
# HAKKANIPUL data saved as CSV
# ICBEPMF1S1 data saved as CSV
# ICBIBANK data saved as CSV
# ICBSONALI1 data saved as CSV
# IFADAUTOS data saved as CSV
# HEIDELBCEM data saved as CSV
# IBBLPBOND data saved as CSV
# IFIC1STMF data saved as CSV
# HRTEX data saved as CSV
# ILFSL data saved as CSV
# IFILISLMF1 data saved as CSV
# INTECH data saved as CSV
# INTRACO data saved as CSV
# IPDC data saved as CSV
# ISLAMIBANK data saved as CSV
# ISLAMIINS data saved as CSV
# ISNLTD data saved as CSV
# ICBAGRANI1 data saved as CSV
# ICB3RDNRB data saved as CSV
# JAMUNAOIL data saved as CSV
# JANATAINS data saved as CSV
# JUTESPINN data saved as CSV
# IDLC data saved as CSV
# JMISMDL data saved as CSV
# IFIC data saved as CSV
# KARNAPHULI data saved as CSV
# KDSALTD data saved as CSV
# KEYACOSMET data saved as CSV
# IMAMBUTTON data saved as CSV
# KOHINOOR data saved as CSV
# ISLAMICFIN data saved as CSV
# KTL data saved as CSV
# JAMUNABANK data saved as CSV
# ITC data saved as CSV
# LEGACYFOOT data saved as CSV
# LIBRAINFU data saved as CSV
# LINDEBD data saved as CSV
# LRGLOBMF1 data saved as CSV
# MAKSONSPIN data saved as CSV
# KAY&QUE data saved as CSV
# KBPPWBIL data saved as CSV
# MATINSPINN data saved as CSV
# MBL1STMF data saved as CSV
# MEGCONMILK data saved as CSV
# KPCL data saved as CSV
# MEGHNACEM data saved as CSV
# KPPL data saved as CSV
# MEGHNAPET data saved as CSV
# MEGHNALIFE data saved as CSV
# MERCINS data saved as CSV
# MHSML data saved as CSV
# LANKABAFIN data saved as CSV
# MIRACLEIND data saved as CSV
# LHBL data saved as CSV
# MALEKSPIN data saved as CSV
# MARICO data saved as CSV
# MLDYEING data saved as CSV
# MONNOCERA data saved as CSV
# MERCANBANK data saved as CSV
# METROSPIN data saved as CSV
# MICEMENT data saved as CSV
# MTB data saved as CSV
# NAVANACNG data saved as CSV
# MIDASFIN data saved as CSV
# NATLIFEINS data saved as CSV
# NCCBLMF1 data saved as CSV
# MITHUNKNIT data saved as CSV
# NEWLINE data saved as CSV
# MJLBD data saved as CSV
# NITOLINS data saved as CSV
# NLI1STMF data saved as CSV
# MONNOSTAF data saved as CSV
# MPETROLEUM data saved as CSV
# NORTHERN data saved as CSV
# NPOLYMAR data saved as CSV
# NORTHRNINS data saved as CSV
# NAHEEACP data saved as CSV
# NTLTUBES data saved as CSV
# NBL data saved as CSV
# NCCBANK data saved as CSV
# OAL data saved as CSV
# OIMEX data saved as CSV
# OLYMPIC data saved as CSV
# ONEBANKLTD data saved as CSV
# NFML data saved as CSV
# PADMALIFE data saved as CSV
# PADMAOIL data saved as CSV
# PARAMOUNT data saved as CSV
# NHFIL data saved as CSV
# PENINSULA data saved as CSV
# PEOPLESINS data saved as CSV
# PHENIXINS data saved as CSV
# NURANI data saved as CSV
# NTC data saved as CSV
# PHPMF1 data saved as CSV
# PIONEERINS data saved as CSV
# POPULAR1MF data saved as CSV
# PLFSL data saved as CSV
# ORIONINFU data saved as CSV
# ORIONPHARM data saved as CSV
# POPULARLIF data saved as CSV
# PRAGATILIF data saved as CSV
# PREMIERBAN data saved as CSV
# PDL data saved as CSV
# PF1STMF data saved as CSV
# PREMIERCEM data saved as CSV
# PREMIERLEA data saved as CSV
# PRIME1ICBA data saved as CSV
# PRIMEBANK data saved as CSV
# PHARMAID data saved as CSV
# PRIMETEX data saved as CSV
# PHOENIXFIN data saved as CSV
# PRIMELIFE data saved as CSV
# PROGRESLIF data saved as CSV
# PTL data saved as CSV
# PURABIGEN data saved as CSV
# QUASEMIND data saved as CSV
# RAHIMTEXT data saved as CSV
# POWERGRID data saved as CSV
# PRAGATIINS data saved as CSV
# RANFOUNDRY data saved as CSV
# RDFOOD data saved as CSV
# REGENTTEX data saved as CSV
# RECKITTBEN data saved as CSV
# PRIMEFIN data saved as CSV
# PRIMEINSUR data saved as CSV
# RELIANCE1 data saved as CSV
# RELIANCINS data saved as CSV
# RENWICKJA data saved as CSV
# PUBALIBANK data saved as CSV
# PROVATIINS data saved as CSV
# RINGSHINE data saved as CSV
# RNSPIN data saved as CSV
# QUEENSOUTH data saved as CSV
# RSRMSTEEL data saved as CSV
# RUNNERAUTO data saved as CSV
# RUPALIINS data saved as CSV
# SAIFPOWER data saved as CSV
# RUPALILIFE data saved as CSV
# SAFKOSPINN data saved as CSV
# SAIHAMTEX data saved as CSV
# SALAMCRST data saved as CSV
# RAKCERAMIC data saved as CSV
# SAMORITA data saved as CSV
# SAMATALETH data saved as CSV
# SANDHANINS data saved as CSV
# SEAPEARL data saved as CSV
# RENATA data saved as CSV
# REPUBLIC data saved as CSV
# SEMLFBSLGF data saved as CSV
# SEMLIBBLSF data saved as CSV
# RUPALIBANK data saved as CSV
# SALVOCHEM data saved as CSV
# SAIHAMCOT data saved as CSV
# SHEPHERD data saved as CSV
# SHURWID data saved as CSV
# SAVAREFR data saved as CSV
# SAPORTL data saved as CSV
# SHYAMPSUG data saved as CSV
# SIBL data saved as CSV
# SILCOPHL data saved as CSV
# SILVAPHL data saved as CSV
# SEBL1STMF data saved as CSV
# SINOBANGLA data saved as CSV
# SKTRIMS data saved as CSV
# SONALIANSH data saved as CSV
# SEMLLECMF data saved as CSV
# SONARGAON data saved as CSV
# SHAHJABANK data saved as CSV
# SHASHADNIM data saved as CSV
# SOUTHEASTB data saved as CSV
# SPCERAMICS data saved as CSV
# SQUARETEXT data saved as CSV
# SPCL data saved as CSV
# STANCERAM data saved as CSV
# STYLECRAFT data saved as CSV
# SUMITPOWER data saved as CSV
# SIMTEX data saved as CSV
# SINGERBD data saved as CSV
# SUNLIFEINS data saved as CSV
# T05Y0715 data saved as CSV
# T05Y0815 data saved as CSV
# T10Y0118 data saved as CSV
# SONARBAINS data saved as CSV
# T10Y0214 data saved as CSV
# SSSTEEL data saved as CSV
# SQURPHARMA data saved as CSV
# T10Y0217 data saved as CSV
# T10Y0216 data saved as CSV
# STANDARINS data saved as CSV
# STANDBANKL data saved as CSV
# T10Y0219 data saved as CSV
# T10Y0218 data saved as CSV
# T10Y0220 data saved as CSV
# T10Y0319 data saved as CSV
# T10Y0317 data saved as CSV
# T10Y0117 data saved as CSV
# T10Y0321 data saved as CSV
# T10Y0119 data saved as CSV
# T10Y0121 data saved as CSV
# T10Y0415 data saved as CSV
# T10Y0416 data saved as CSV
# T10Y0418 data saved as CSV
# T10Y0420 data saved as CSV
# T10Y0419 data saved as CSV
# T10Y0215 data saved as CSV
# T10Y0519 data saved as CSV
# T10Y0421 data saved as CSV
# T10Y0221 data saved as CSV
# T10Y0520 data saved as CSV
# T10Y0614 data saved as CSV
# T10Y0318 data saved as CSV
# T10Y0617 data saved as CSV
# T10Y0615 data saved as CSV
# T10Y0616 data saved as CSV
# T10Y0320 data saved as CSV
# T10Y0414 data saved as CSV
# T10Y0618 data saved as CSV
# T10Y0620 data saved as CSV
# T10Y0621 data saved as CSV
# T10Y0717 data saved as CSV
# T10Y0619 data saved as CSV
# T10Y0721 data saved as CSV
# T10Y0720 data saved as CSV
# T10Y0817 data saved as CSV
# T10Y0816 data saved as CSV
# T10Y0517 data saved as CSV
# T10Y0518 data saved as CSV
# T10Y0820 data saved as CSV
# T10Y0819 data saved as CSV
# T10Y0818 data saved as CSV
# T10Y0521 data saved as CSV
# T10Y0919 data saved as CSV
# T10Y0918 data saved as CSV
# T10Y0916 data saved as CSV
# T10Y0917 data saved as CSV
# T10Y0921 data saved as CSV
# T10Y1014 data saved as CSV
# T10Y0920 data saved as CSV
# T10Y1016 data saved as CSV
# T10Y0719 data saved as CSV
# T10Y0718 data saved as CSV
# T10Y0814 data saved as CSV
# T10Y1117 data saved as CSV
# T10Y1118 data saved as CSV
# T10Y1120 data saved as CSV
# T10Y1214 data saved as CSV
# T10Y1215 data saved as CSV
# T10Y0821 data saved as CSV
# T10Y1218 data saved as CSV
# T10Y1219 data saved as CSV
# T10Y1019 data saved as CSV
# T10Y1017 data saved as CSV
# T10Y1018 data saved as CSV
# T10Y1116 data saved as CSV
# T15Y0123 data saved as CSV
# T15Y0125 data saved as CSV
# T15Y0223 data saved as CSV
# T10Y1213 data saved as CSV
# T15Y0224 data saved as CSV
# T10Y1217 data saved as CSV
# T15Y0323 data saved as CSV
# T10Y1216 data saved as CSV
# T15Y0423 data saved as CSV
# T15Y0325 data saved as CSV
# T10Y1220 data saved as CSV
# T15Y0424 data saved as CSV
# T15Y0425 data saved as CSV
# T15Y0524 data saved as CSV
# T15Y0124 data saved as CSV
# T15Y0525 data saved as CSV
# T15Y0526 data saved as CSV
# T15Y0225 data saved as CSV
# T15Y0226 data saved as CSV
# T15Y0324 data saved as CSV
# T15Y0626 data saved as CSV
# T15Y0624 data saved as CSV
# T15Y0625 data saved as CSV
# T15Y0326 data saved as CSV
# T15Y0722 data saved as CSV
# T15Y0723 data saved as CSV
# T15Y0724 data saved as CSV
# T15Y0725 data saved as CSV
# T15Y0822 data saved as CSV
# T15Y0826 data saved as CSV
# T15Y0823 data saved as CSV
# T15Y0825 data saved as CSV
# T15Y0426 data saved as CSV
# T15Y0922 data saved as CSV
# T15Y0523 data saved as CSV
# T15Y0923 data saved as CSV
# T15Y0925 data saved as CSV
# T15Y1023 data saved as CSV
# T15Y0926 data saved as CSV
# T15Y1022 data saved as CSV
# T15Y0924 data saved as CSV
# T15Y1025 data saved as CSV
# T15Y0623 data saved as CSV
# T15Y1122 data saved as CSV
# T15Y1024 data saved as CSV
# T15Y1125 data saved as CSV
# T15Y1222 data saved as CSV
# T15Y1224 data saved as CSV
# T20Y0129 data saved as CSV
# T20Y0131 data saved as CSV
# T20Y0229 data saved as CSV
# T15Y0824 data saved as CSV
# T20Y0328 data saved as CSV
# T20Y0231 data saved as CSV
# T20Y0330 data saved as CSV
# T20Y0329 data saved as CSV
# T20Y0429 data saved as CSV
# T20Y0428 data saved as CSV
# T15Y1123 data saved as CSV
# T15Y1223 data saved as CSV
# T15Y1225 data saved as CSV
# T20Y0128 data saved as CSV
# T20Y0528 data saved as CSV
# T20Y0228 data saved as CSV
# T20Y0530 data saved as CSV
# T20Y0531 data saved as CSV
# T20Y0628 data saved as CSV
# T20Y0230 data saved as CSV
# T20Y0630 data saved as CSV
# T20Y0631 data saved as CSV
# T20Y0727 data saved as CSV
# T20Y0729 data saved as CSV
# T20Y0828 data saved as CSV
# T20Y0430 data saved as CSV
# T20Y0431 data saved as CSV
# T20Y0831 data saved as CSV
# T20Y0830 data saved as CSV
# T20Y0629 data saved as CSV
# T20Y0928 data saved as CSV
# T20Y0927 data saved as CSV
# T20Y0728 data saved as CSV
# T20Y0730 data saved as CSV
# T20Y0731 data saved as CSV
# T20Y0827 data saved as CSV
# T20Y0931 data saved as CSV
# T20Y1027 data saved as CSV
# T20Y1030 data saved as CSV
# T20Y1127 data saved as CSV
# T20Y1128 data saved as CSV
# T20Y0829 data saved as CSV
# T20Y1227 data saved as CSV
# T20Y1229 data saved as CSV
# T20Y1230 data saved as CSV
# T5Y0114 data saved as CSV
# T20Y0930 data saved as CSV
# T20Y1028 data saved as CSV
# T5Y0116 data saved as CSV
# T20Y1029 data saved as CSV
# T5Y0213 data saved as CSV
# T20Y1130 data saved as CSV
# T20Y1228 data saved as CSV
# T5Y0216 data saved as CSV
# T5Y0215 data saved as CSV
# T5Y0112 data saved as CSV
# T5Y0313 data saved as CSV
# T5Y0113 data saved as CSV
# T5Y0314 data saved as CSV
# T5Y0315 data saved as CSV
# T5Y0316 data saved as CSV
# T5Y0412 data saved as CSV
# T5Y0415 data saved as CSV
# T5Y0416 data saved as CSV
# T5Y0115 data saved as CSV
# T5Y0615 data saved as CSV
# T5Y0514 data saved as CSV
# T5Y0613 data saved as CSV
# T5Y0616 data saved as CSV
# T5Y0212 data saved as CSV
# T5Y0716 data saved as CSV
# T5Y0214 data saved as CSV
# T5Y0811 data saved as CSV
# T5Y0813 data saved as CSV
# T5Y0814 data saved as CSV
# T5Y0414 data saved as CSV
# T5Y0911 data saved as CSV
# T5Y0912 data saved as CSV
# T5Y0516 data saved as CSV
# T5Y0712 data saved as CSV
# T5Y0714 data saved as CSV
# T5Y0713 data saved as CSV
# T5Y0915 data saved as CSV
# T5Y1012 data saved as CSV
# T5Y0916 data saved as CSV
# T5Y0812 data saved as CSV
# T5Y1015 data saved as CSV
# T5Y1111 data saved as CSV
# T5Y0816 data saved as CSV
# T5Y1112 data saved as CSV
# T5Y1113 data saved as CSV
# T5Y1114 data saved as CSV
# T5Y1115 data saved as CSV
# T5Y0913 data saved as CSV
# T5Y1214 data saved as CSV
# T5Y1213 data saved as CSV
# T5Y0914 data saved as CSV
# TAKAFULINS data saved as CSV
# T5Y1215 data saved as CSV
# T5Y1011 data saved as CSV
# T5Y1013 data saved as CSV
# TITASGAS data saved as CSV
# TOSRIFA data saved as CSV
# TRUSTBANK data saved as CSV
# T5Y1014 data saved as CSV
# UCB data saved as CSV
# UNIONCAP data saved as CSV
# UNIQUEHRL data saved as CSV
# UNITEDAIR data saved as CSV
# T5Y1211 data saved as CSV
# T5Y1212 data saved as CSV
# USMANIAGL data saved as CSV
# UTTARAFIN data saved as CSV
# TALLUSPIN data saved as CSV
# VAMLRBBF data saved as CSV
# TRUSTB1MF data saved as CSV
# TUNGHAI data saved as CSV
# VFSTDL data saved as CSV
# WATACHEM data saved as CSV
# YPL data saved as CSV
# ZAHEENSPIN data saved as CSV
# UNITEDINS data saved as CSV
# ZAHINTEX data saved as CSV
# ZEALBANGLA data saved as CSV
# UNITEDFIN data saved as CSV
# UPGDCL data saved as CSV
# UTTARABANK data saved as CSV
# VAMLBDMF1 data saved as CSV
# WMSHIPYARD data saved as CSV

# %% [markdown]
# **Data Pre-processing Done!**
